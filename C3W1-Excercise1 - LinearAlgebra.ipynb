# %%
n = 3
m = 2
n * m
# Out:
# 6

# %%
import numpy as np

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])

# %%
a.dot(b)
# Out:
# 32

# %%
ma = np.array([[1,2,3],[7,8,9]])
mb = np.array([4,5,6])

# %%
ma.dot(mb)
# Out:
# array([ 32, 122])
